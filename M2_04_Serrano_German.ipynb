# %% [markdown]
# # Ejercicios Modulo 2. Tipos avanzados
#
# Consideraciones a tener en cuenta:
#
# * Guardar este documento con el siguiente formato para su entrega: __M2_04_nombre_apellido1_apellido2__
# * Realizar los ejercicios con las herramientas vistas en las sesiones. Aún no hemos llegado a condicionales ni bucles
# * Comentar el código
# * Utilizar nombres de variables apropiados, si vais a guardar una nota, llamar a esa variable nota, no n o x

# %% [markdown]
# ## Ejercicios de tipos avanzados

# %% [markdown]
# **1) Trabajemos con listas y tuplas**
# * Crea una lista y una tupla que contenga strings (al menos 3 elementos). Tematica libre, sobre lo que quieras, vehiculos, comida, música, etc.
# * Muestra la lista y la tupla
# * Muestra el 2º elemento de la lista y el penúltimo de la tupla
# * Modifica (si se puede) algún elemento de la lista y de la tupla. Y mostrar el resultado
# * Muestra el tamaño de la lista y de la tupla
# * Realiza una búsqueda de un elemento dentro de la lista y de la tupla. Mostrar si devuelve True o False
# * Añade (si se puede) algún elemento a la lista y a la tupla. Mostrar de nuevo la lista y la tupla para verificar si se ha realizado correctamente la acción.
# * Borra o elimina (si se puede) el contenido de la lista y de la tupla. Mosstrar de nuevo la lista y la tupla para verificar si se ha realizado correctamente la acción

# %%
lista_generos = ["Rock", "Jazz", "Reggae"]
tupla_generos = ("Pop", "Clásica", "Hip-Hop")

print("Lista de géneros:", lista_generos)
print("Tupla de géneros:", tupla_generos)

print(f"\n2º elemento de la lista: {lista_generos[1]}")
print(f"Penúltimo elemento de la tupla: {tupla_generos[-2]}")

print("\n--- Intentando modificar elementos ---")
lista_generos[0] = "Metal"
print(f"Lista después de modificar el 1er elemento: {lista_generos}")

print("Tuplas no se pueden modificar (son inmutables)")

print(f"\nTamaño de la lista: {len(lista_generos)}")
print(f"Tamaño de la tupla: {len(tupla_generos)}")

elemento_busqueda = "Jazz"
print(f"\n¿'{elemento_busqueda}' está en la lista? {elemento_busqueda in lista_generos}")
print(f"¿'{elemento_busqueda}' está en la tupla? {elemento_busqueda in tupla_generos}")

print("\n--- Añadiendo elementos ---")
lista_generos.append("Blues")
print(f"Lista después de añadir 'Blues': {lista_generos}")

tupla_generos = tupla_generos + ("Electrónica",)
print(f"Tupla después de añadir 'Electrónica': {tupla_generos}")

print("\n--- Eliminando contenido ---")
lista_generos.clear()
print(f"Lista después de limpiarla: {lista_generos}")

tupla_generos = ()
print(f"Tupla después de vaciarla: {tupla_generos}")
# Out:
# Lista de géneros: ['Rock', 'Jazz', 'Reggae']
# Tupla de géneros: ('Pop', 'Clásica', 'Hip-Hop')
#
# 2º elemento de la lista: Jazz
# Penúltimo elemento de la tupla: Clásica
#
# --- Intentando modificar elementos ---
# Lista después de modificar el 1er elemento: ['Metal', 'Jazz', 'Reggae']
# Tuplas no se pueden modificar (son inmutables)
#
# Tamaño de la lista: 3
# Tamaño de la tupla: 3
#
# ¿'Jazz' está en la lista? True
# ¿'Jazz' está en la tupla? False
#
# --- Añadiendo elementos ---
# Lista después de añadir 'Blues': ['Metal', 'Jazz', 'Reggae', 'Blues']
# Tupla después de añadir 'Electrónica': ('Pop', 'Clásica', 'Hip-Hop', 'Electrónica')
#
# --- Eliminando contenido ---
# Lista después de limpiarla: []
# Tupla después de vaciarla: ()

# %% [markdown]
# **2) Trabajemos con sets y diccionarios**
# * Crea una set y un diccionario que contengan strings (al menos 3 elementos en el caso del set y 3 conjuntos de clave:valor en el caso del diccionario). Tematica libre, sobre lo que quieras, vehiculos, comida, música, etc.
# * Muestra el set y el diccionario
# * Muestra (si se puede) el 2º elemento del set y el valor del primer clave-valor del diccionario
# * Modifica (si se puede) algún elemento del set o del diccionario. Y mostrar el resultado
# * Muestra el tamaño del set y del diccionario
# * Realiza una búsqueda de un elemento dentro del set y dentro del diccionario. Mostrar si devuelve True o False
# * Añade (si se puede) algún elemento al set y algun clave-valor al diccionario. Mostrar de nuevo el set y el diccionario para verificar si se ha realizado correctamente la acción.
# * Borra o elimina (si se puede) el contenido del set y del diccionario. Mosstrar de nuevo el set y el diccionario para verificar si se ha realizado correctamente la acción

# %%
set_instrumentos = {"Guitarra", "Piano", "Violín"}
diccionario_instrumentos = {
    "Guitarra": "Cuerda",
    "Piano": "Teclado",
    "Violín": "Cuerda"
}

print("Set de instrumentos:", set_instrumentos)
print("Diccionario de instrumentos:", diccionario_instrumentos)

print("\n--- Acceso a elementos ---")
set_como_lista = list(set_instrumentos)
print(f"2º elemento del set (convertido a lista): {set_como_lista[1]}")

primer_valor = list(diccionario_instrumentos.values())[0]
print(f"Valor del primer clave-valor del diccionario: {primer_valor}")

print("\n--- Modificando elementos ---")
set_instrumentos.discard("Guitarra")
set_instrumentos.add("Batería")
print(f"Set después de modificar: {set_instrumentos}")

diccionario_instrumentos["Piano"] = "Percusión"
print(f"Diccionario después de modificar: {diccionario_instrumentos}")

print(f"\nTamaño del set: {len(set_instrumentos)}")
print(f"Tamaño del diccionario: {len(diccionario_instrumentos)}")

print("\n--- Búsquedas ---")
elemento_set = "Batería"
print(f"¿'{elemento_set}' está en el set? {elemento_set in set_instrumentos}")

clave_dict = "Violín"
print(f"¿'{clave_dict}' está en el diccionario? {clave_dict in diccionario_instrumentos}")

print("\n--- Añadiendo elementos ---")
set_instrumentos.add("Flauta")
print(f"Set después de añadir 'Flauta': {set_instrumentos}")

diccionario_instrumentos["Flauta"] = "Viento"
print(f"Diccionario después de añadir 'Flauta': {diccionario_instrumentos}")

print("\n--- Eliminando contenido ---")
set_instrumentos.clear()
print(f"Set después de limpiar: {set_instrumentos}")

diccionario_instrumentos.clear()
print(f"Diccionario después de limpiar: {diccionario_instrumentos}")
# Out:
# Set de instrumentos: {'Piano', 'Violín', 'Guitarra'}
# Diccionario de instrumentos: {'Guitarra': 'Cuerda', 'Piano': 'Teclado', 'Violín': 'Cuerda'}
#
# --- Acceso a elementos ---
# 2º elemento del set (convertido a lista): Violín
# Valor del primer clave-valor del diccionario: Cuerda
#
# --- Modificando elementos ---
# Set después de modificar: {'Batería', 'Piano', 'Violín'}
# Diccionario después de modificar: {'Guitarra': 'Cuerda', 'Piano': 'Percusión', 'Violín': 'Cuerda'}
#
# Tamaño del set: 3
# Tamaño del diccionario: 3
#
# --- Búsquedas ---
# ¿'Batería' está en el set? True
# ¿'Violín' está en el diccionario? True
#
# --- Añadiendo elementos ---
# Set después de añadir 'Flauta': {'Batería', 'Flauta', 'Piano', 'Violín'}
# Diccionario después de añadir 'Flauta': {'Guitarra': 'Cuerda', 'Piano': 'Percusión', 'Violín': 'Cuerda', 'Flauta': 'Viento'}
#
# --- Eliminando contenido ---
# Set después de limpiar: set()
# Diccionario después de limpiar: {}

# %% [markdown]
# **3) Realizar un programa que pida al usuario 3 números que pueden ser flotantes (no es necesario realizar bucles aún, podemos repetir el código), estos números se deberán introducir en una lista. Cuando se haya finalizado la introducción de los datos, se mostrará el sumatorio de toda la lista. Guardar el sumatorio en una variable que se llame "sumatorio"**
#
# *Ayuda: Existe una función llamada sum(lista) ¡Pruébalo!*

# %%
numero1 = float(input("Introduce el primer número: "))
numero2 = float(input("Introduce el segundo número: "))
numero3 = float(input("Introduce el tercer número: "))

numeros = [numero1, numero2, numero3]
print(f"\nLa lista de números introducidos es: {numeros}")
sumatorio = sum(numeros)

print(f"El sumatorio de los números es: {sumatorio}")
# Out:
# La lista de números introducidos es: [5.67, 5.89, 3.65]
# El sumatorio de los números es: 15.209999999999999

# %% [markdown]
# **4) Sobre el ejercicio anterior, queremos mostrar la media aritmética de los elementos de esa lista. Indicar la instrucción necesaria para obtenerla.**
#
# *En este caso sabemos que el número de elementos que ha introducido el usuario es 3, pero en otra ocasión podría ser diferente, por lo tanto, no hagáis referencia al número 3 en ningún sitio*

# %%
media_aritmetica = sum(numeros) / len(numeros)

print(f"La media aritmética de los números es: {media_aritmetica}")
# Out:
# La media aritmética de los números es: 5.069999999999999
